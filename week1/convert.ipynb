# %%
import pandas as pd
import csv
import json
import random
df_inter = pd.read_csv('./international.csv')
df_domes = pd.read_csv('./domestic.csv')

# %%
def csv_to_json(df, name):
    asn = df.ASN.unique()
    nodes = []

    sum_bw = []
    all_sum = 0
    
    for index, i in enumerate(asn):
        n = df[df['ASN']== i]['Bandwidth'].sum() + df[df['ASN-Source']== i]['Bandwidth'].sum()
        all_sum += n
        sum_bw.append(n)
    
    for index,i in enumerate(sum_bw):
        x = i
        a = asn[index]
        j = index - 1
        while j >= 0 and sum_bw[j] > x:
            sum_bw[j+1] = sum_bw[j]
            asn[j+1] = asn[j]
            j = j - 1
        sum_bw[j+1] = x
        asn[j+1] = a

    print(all_sum)
    for index, i in enumerate(asn):
        r = lambda: random.randint(0,255)
        color = '#%02X%02X%02X' % (r(),r(),r())
        label = (df[df['ASN']==i]['Name'].unique())[0]
        print(label)
        node = {
            "color": color,
            "label": label,
            "x": random.randint(-1000,1000),
            "y": random.randint(-1000,1000),
            "attributes": {},
            "id": i,
            "size": (sum_bw[index]/all_sum)*300
        }
        nodes.append(node)
    edges = []
    for index, row in df.iterrows():
        edge = {
            "sourceID": row['ASN-Source'],
            "attributes": {},
            "targetID": row['ASN'],
            "size": 1
        }
        edges.append(edge)
    filejson = json.dumps({'nodes': nodes, 'edges': edges}, indent=4, separators=(',', ': '))
    with open('./' + name + '.json', 'w') as file:
        file.write(filejson)

# %%
csv_to_json(df_inter, 'international')
# Out:
# 15669.002000000004
# B Network Solution (BNS)
# INFONET
# ServeNET
# TATA  (IN)
# Lao Gateway (LA)
# Airtel (SG)
# Milcom
# Metrabyte
# NIPA.CLOUD
# Ezecom (KH)
# SIAMDATA
# SIAMDATA
# CHT-I HiNet (TW)
# LG DACOM (KR)
# 1-to-All
# Loxley
# Planetcom (LA)
# A-Net
# ICT MOF
# AWN-IIG (SBN)
# MILCOM
# Sky Telecom (LA)
# Dots Solutions
# 2S1N
# PTT ICT
# Pacific Internet
# ISSP
# SKY Telecom (Lao)
# PLDT (PH)
# VNPT Corp (VN)
# DTAG (FR)
# Comnet (DE)
# HostServer (DE)
# NFOrce (DE)
# CITYNET (DE)
# GAMEFORGE (DE)
# Telehouse (DE)
# Catalyst2 (UK)
# ColocationIX (UK)
# Zen Internet (UK)
# NYIIX (US)
# Atlantic Metro (US)
# OTARO
# NTC (KH)
# Spotify (SG)
# Tencent (SG)
# QUANTIL (HK)
# TEIN4 (HK)
# JGN-IX (SG)
# NTT (TH)
# Samart Infonet
# GIN
# SOFTBANK (HK)
# NTT APAC (HK)
# HostEurope (DE)
# GENIUSNETWORKS (DE)
# Microsoft (SG)
# HGC (HK)
# UNITEL (LA)
# TCCT-ISP
# Beeline (LA)
# ETL (LA)
# KIRZ
# AT&T (DE)
# nLayer (US)
# LAO Telecom (LA)
# Global Cloud Xchange(SG)
# KSC
# MPT (MM)
# CHT-I (TW)
# Telecom Italia (SG)
# TOT LLI
# JPNAP (JP)
# NLIX (NL)
# Vodafone  (FR)
# 1-Net (SG)
# Globe Telecom (SG)
# SGIX (SG)
# Ji-NET
# BIGLOBE (SG)
# CBN Networks (SG)
# Extreme Broadband (SG)
# Forcepoint (SG)
# HitachiSunway (SG)
# iiNet (SG)
# Maxis (SG)
# NAP Info (SG)
# NewMedia Express(SG)
# ReadySpace Pte Ltd (SG)
# SecureAX (SG)
# SINET (SG)
# Telecom Cambodia (SG)
# Verizon (SG)
# XLNET (SG)
# Microsoft (SG)
# Pacnet (SG)
# Sprint (US)
# Bandwidth Technologies (NL)
# InterConnect (NL)
# Mainsoft (NL)
# PLEX (NL)
# Zayo (NL)
# ATOM86 (NL)
# Areti Internet (SG)
# British Telecom (SG)
# Dhiraagu (SG)
# FASTLY (SG)
# GoDaddy (SG)
# IIJ (SG)
# Kakao (SG)
# Wargaming (SG)
# Wharf T&T (SG)
# BhutanTelecom (SG)
# HERE Global BV (SG)
# Level3 GBLX (SG)
# ZSCALER (SG)
# ACME (HK)
# ANCHNET (HK)
# Anycast (HK)
# Asia Pacific Telecom (HK)
# Baidu (HK)
# CNS-KBT (HK)
# i4HK (HK)
# Rackspace (HK)
# VTC (HK)
# Dialpad (HK)
# Akamai (HK)
# Limelight (SG)
# SKB (KR)
# Verizon (US)
# Pacific Internet (SG)
# KDDI (HK)
# INET
# FERAL (NL)
# OPENCARRIER (NL)
# INDOSAT (SG)
# FPT Telecom (HK)
# HKBN (HK)
# NetActuate (HK)
# LINX (UK)
# GTT (SG)
# 1&1 Internet (NL)
# Liquid Telecom (NL)
# MANDA (NL)
# Netrouting (NL)
# Sunrise (NL)
# Telenor (NL)
# Voxility (NL)
# SOCO (NL)
# WIOCC (NL)
# DOSARREST (SG)
# China Telecom (HK)
# Blizzard (NL)
# Equinix (FR)
# GlobalNet (MM)
# OpenDNS (SG)
# Core-Backbone (SG)
# Media Net (SG)
# Moratelindo (SG
# MyRepublic (SG)
# Qatar Telecom (SG)
# TELIN (SG)
# Trans Hybrid Communication (SG)
# Voxel (SG)
# AOFEI (SG)
# Wikimedia (SG)
# Equinix (US)
# AMS-IX (NL)
# NexusGuard (SG)
# Any2Coresite (US)
# StarHub (SG)
# Digital Ocean (SG)
# France IX (FR)
# Biznet Networks (SG)
# EZNETSOLS (SG)
# Internet Harbor Global (SG)
# PCH (SG)
# CLARA (NL)
# PROEN Internet
# GTC (MY)
# TM (MY)
# LINX (UK)
# Alibaba (SG)
# Linkedin (SG)
# SG.GS (SG)
# Swisscom (SG)
# Viewqwest (SG)
# Vocus (AU)
# EZIT (SG)
# IPTransit (SG)
# Leaseweb (SG)
# OVH (SG)
# AT&T (NL)
# TOT LLI
# TeliaSonera (HK)
# Etisalat (UAE)
# DE-CIX (DE)
# CDNetworks (SG)
# Netnod (SG)
# Cogent (SG)
# Level3  (US)
# SingTel (SG)
# Zenlayer (SG)
# IP ServerOne (SG)
# SparkStation (SG)
# SuperInternet (SG)
# Symphony-ISP
# TOT-IDC
# BBIX (HK)
# Expereo (SG)
# Dailymotion (SG)
# Dropbox (SG)
# CCT (SG)
# PCCW (HK)
# AMS-IX (AN)
# MOE
# SoftLayer (SG)
# TATA (SG)
# PCH (SG)
# HKIX (HK)
# Twitter (SG)
# Yahoo (SG)
# Telstra (HK)
# Akamai (SG)
# CloudFlare (SG)
# NTT (SG)
# LimeLight (SG)
# Amazon (SG)
# CS Loxinfo
# VALVE (SG)
# Amazon (SG)
# Equinix (SG)
# Hurricane  (HK)
# Apple (SG)
# UniNet
# NHN (SG)
# Microsoft (HK)
# Netflix (SG)
# Twitch  (SG)
# CAT-ISP
# CAT ON Net
# UIH/ BEENET
# EdgeCast (SG)
# Telenor Global (SG)
# Equinix (SG)
# TOT ISP
# BB Connect-IIG
# Triple T Internet/ Triple T Broadband
# Dtac Trinet
# True Internet Corporation
# Facebook (SG)
# Google (HK)
# TOT-IIG
# DTAC (IIG)

# %%
csv_to_json(df_domes, 'domestic')
# Out:
# 14748.32
# MILCOM
# ICT MOF
# Telstra
# 101 Global
# 1-TO-ALL
# BB Connect-IX (UIH/BEENET)
# GIN
# EGA
# AIT
# ServeNET
# 2S1N
# PTT ICT
# SAMART Infonet
# Dots Solutions
# ISSP
# Metrabyte
# BB Connect
# Pacific Internet
# KSC
# ISSP
# POP-IDC
# Ji-NET
# NTT (TH)
# TOT LLI
# INOX
# KIRZ
# Siam Data
# TOT-IDC
# MOE
# Symphony-ISP
# SIAMDATA
# UniNet
# UIH/ BEENET
# CAT ON Net
# NIPA.CLOUD
# CS Loxinfo
# A-Net
# Dtac Trinet
# INET
# TCCT-ISP
# OTARO
# True Internet Corporation
# DTAC-IX
# BKNIX
# Loxley
# TOT ISP
# CAT-ISP
# PROEN Internet
# SYMC-IX
# Triple T Internet/ Triple T Broadband
# TOT-IX
# TCCT-IX
# Jastel-IX
# CSL-IX
# TIG-IX
# CAT-IX (Bangrak/Nonthaburi)
# AWN-IX
